# %%
from tkinter import *
import tkinter as tk
from tkinter import messagebox
from PIL import ImageTk,Image
from tkinter import ttk
import openpyxl,xlrd
from openpyxl import Workbook
import pathlib
import re
import pandas as pd

# %%
def submit():
    
    global background
    name = name_entry.get()
    res = any(chr.isdigit() for chr in name)
    regex = re.compile('[@_!#$%^&*()<>?/\|}{~:]')
    if(name=="" or name==" " or res or regex.search(name) != None):
        messagebox.showinfo("Movie Recommendation", "Please enter a valid Name")
    
    else:
                
        win = Toplevel(window)
        win.title("Personalised Window")
        win.geometry("1000x1000")
    
        background = ImageTk.PhotoImage(Image.open("Img5.jpg"))

        my_canvas = Canvas(win, width = 1000, height = 1000)
        my_canvas.pack(fill = "both", expand = True)

        my_canvas.create_image(0,0, image=background, anchor="nw")
        my_canvas.create_text(800,200,text="Hi, "+name+" !",font = ("Arial Bold",30),fill="white")
        my_canvas.create_text(800,250,text="How can we help you? " ,font = ("Arial Bold",30),fill="white")

        def top10func():
                       
            
            def datatop():
                
                year = genre.get()
                
                if(year=='2016'):
                    
                    def resizer1(a):
                        
                        global bg21,resized_bg1,new_bg1
                        bg21 = Image.open("2016.jpg")
                        resized_bg1 = bg21.resize((a.width,a.height), Image.ANTIALIAS)
                        new_bg1 = ImageTk.PhotoImage(resized_bg1)
                        canvas.create_image(0,0, image=new_bg1, anchor="nw")
                        
                        canvas.create_text(800,100,text = "Top Movies of 2016",font = ("Arial Bold",20),fill="#00008B")                      

                        canvas.create_text(300,200,text = "The Salesman",font = ("Arial Bold",16),fill="#FF6347")
                        canvas.create_text(290,250,text = "Rating - 7.8",font = ("Arial Bold",16),fill="#FF69B4")
                        canvas.create_text(905,200,text = '''While both participating in a production of "Death of a Salesman,"a teacher's''',font = ("Arial Bold",12),fill="black")
                        canvas.create_text(898,225,text = '''wife is assaulted in her new home, which leaves him determined to find the''',font = ("Arial Bold",12),fill="black")
                        canvas.create_text(810,250,text = '''perpetrator over his wife's traumatized objections. ''',font = ("Arial Bold",12),fill="black")
                       
                        canvas.create_text(300,400,text = "Silence ",font = ("Arial Bold",16),fill="#FF6347")
                        canvas.create_text(290,450,text = "Rating - 7.2 ",font = ("Arial Bold",16),fill="#FF69B4")
                        canvas.create_text(875,400,text = '''In the 17th century, two Portuguese Jesuit priests travel to Japan in ''',font = ("Arial Bold",12),fill="black")
                        canvas.create_text(875,425,text = '''an attempt to locate their mentor, who is rumored to have committed''',font = ("Arial Bold",12),fill="black")
                        canvas.create_text(770,450,text = '''apostasy, and to propagate Catholicism.''',font = ("Arial Bold",12),fill="black")
                       
                                  
                        canvas.create_text(300,600,text = "La La Land ",font = ("Arial Bold",16),fill="#FF6347")
                        canvas.create_text(290,650,text = "Rating - 8.0 ",font = ("Arial Bold",16),fill="#FF69B4")
                        canvas.create_text(875,600,text = '''While navigating their careers in Los Angeles, a pianist and an actress''',font = ("Arial Bold",12),fill="black")
                        canvas.create_text(875,625,text = '''fall in love while attempting to reconcile their aspirations for the future.''',font = ("Arial Bold",12),fill="black")
                        
                        
                        
                        
                        
                        
                        
                    
                    global bg1
                    win8 = Toplevel(win1)
                    win8.title("Top 5 Recommendations")
                    win8.geometry("1000x1000")
                    
                    bg1 = ImageTk.PhotoImage(Image.open("2016.jpg"))

                    canvas = Canvas(win8,width = 1000, height = 1000)
                    canvas.pack(fill = "both", expand = True)
                    canvas.create_image(0,0, image=bg1, anchor="nw")

                    

                    
                    canvas.create_text(693,460,text = "The Salesman",font = ("Arial Bold",18),fill="white")
                    canvas.create_text(693,560,text = "Silence ",font = ("Arial Bold",18),fill="white")
                    canvas.create_text(693,660,text = "La La Land ",font = ("Arial Bold",18),fill="white")
                    
                    
                    win8.bind('<Configure>',resizer1)
                    
                    
                    
                elif(year=='2017'):
                    
                    def resizer2(b):
                        global bg22,resized_bg2,new_bg2
                        bg22 = Image.open("2017.jpg")
                        resized_bg2 = bg22.resize((b.width,b.height), Image.ANTIALIAS)
                        new_bg2 = ImageTk.PhotoImage(resized_bg2)
                        canvas.create_image(0,0, image=new_bg2, anchor="nw")
                        
                                               
                        canvas.create_text(800,100,text = "Top Movies of 2017",font = ("Arial Bold",20),fill="#ea4f2e")
                        
                        canvas.create_text(300,200,text = "Lady Bird",font = ("Arial Bold",16),fill="#8B4513")
                        canvas.create_text(290,250,text = "Rating - 7.4",font = ("Arial Bold",16),fill="#C71585")
                        canvas.create_text(890,200,text = '''In 2002, an artistically inclined seventeen-year-old girl''',font = ("Arial Bold",12),fill="black")
                        canvas.create_text(835,225,text = '''comes of age in Sacramento, California.''',font = ("Arial Bold",12),fill="black")
                    
                        
                        canvas.create_text(300,400,text = "Dunkirk ",font = ("Arial Bold",16),fill="#8B4513")
                        canvas.create_text(290,450,text = "Rating - 7.8 ",font = ("Arial Bold",16),fill="#C71585")
                        canvas.create_text(890,400,text = '''Allied soldiers from Belgium, the British Commonwealth and Empire,''',font = ("Arial Bold",12),fill="black")
                        canvas.create_text(890,425,text = '''and France are surrounded by the German Army and evacuated during''',font = ("Arial Bold",12),fill="black")
                        canvas.create_text(840,450,text = '''a fierce battle in World War II.''',font = ("Arial Bold",12),fill="black")
                        
                        canvas.create_text(300,600,text = "Coco ",font = ("Arial Bold",16),fill="#8B4513")
                        canvas.create_text(290,650,text = "Rating - 8.4",font = ("Arial Bold",16),fill="#C71585")
                        canvas.create_text(890,600,text = '''Aspiring musician Miguel, confronted with his family's''',font = ("Arial Bold",12),fill="black")
                        canvas.create_text(890,625,text = '''ancestral ban on music, enters the Land of the Dead''',font = ("Arial Bold",12),fill="black")
                        canvas.create_text(890,650,text = '''to find his great-great-grandfather, a legendary singer.''',font = ("Arial Bold",12),fill="black")
                        
                        
                        
                    
                    global bg2
                    win9 = Toplevel(win1)
                    win9.title("Top 5 Recommendations")
                    win9.geometry("1000x1000")
                    
                    bg2 = ImageTk.PhotoImage(Image.open("2017.jpg"))

                    canvas = Canvas(win9,width = 1000, height = 1000)
                    canvas.pack(fill = "both", expand = True)
                    canvas.create_image(0,0, image=bg2, anchor="nw")

                    

                    canvas.create_text(693,360,text = "Lady Bird",font = ("Arial Bold",18),fill="white")
                    canvas.create_text(693,560,text = "Dunkirk ",font = ("Arial Bold",18),fill="white")
                    canvas.create_text(693,660,text = "Coco ",font = ("Arial Bold",18),fill="white")
                    
                    
                    win9.bind('<Configure>',resizer2)
                    
                elif(year=='2018'):
                    
                    def resizer(e):
                        global bg20,resized_bg,new_bg
                        bg20 = Image.open("2018.jpg")
                        resized_bg = bg20.resize((e.width,e.height), Image.ANTIALIAS)
                        new_bg = ImageTk.PhotoImage(resized_bg)
                        canvas.create_image(0,0, image=new_bg, anchor="nw")
                        
                        canvas.create_text(800,100,text = "Top Movies of 2018",font = ("Arial Bold",20),fill="#556B2F")
                        
                        canvas.create_text(416,200,text = "Avengers Infinity War ",font = ("Arial Bold",16),fill="#D2691E")
                        canvas.create_text(406,250,text = "Rating - 8.4 ",font = ("Arial Bold",16),fill="#FF8C00")
                        canvas.create_text(980,200,text = '''The Avengers and their allies must be willing to sacrifice all in ''',font = ("Arial Bold",12),fill="black")
                        canvas.create_text(980,225,text = '''an attempt to defeat the powerful Thanos before his blitz of devastation''',font = ("Arial Bold",12),fill="black")
                        canvas.create_text(980,250,text = '''and ruin puts an end to the universe. ''',font = ("Arial Bold",12),fill="black")
                        
                        canvas.create_text(416,400,text = "Black Panther",font = ("Arial Bold",16),fill="#D2691E")
                        canvas.create_text(406,450,text = "Rating - 7.3",font = ("Arial Bold",16),fill="#FF8C00")
                        canvas.create_text(980,400,text = '''T'Challa, heir to the hidden but advanced kingdom of Wakanda,''',font = ("Arial Bold",12),fill="black")
                        canvas.create_text(980,425,text = ''' must step forward to lead his people into a new future and''',font = ("Arial Bold",12),fill="black")
                        canvas.create_text(980,450,text = '''must confront a challenger from his country's past. ''',font = ("Arial Bold",12),fill="black")
                        
                        
                        canvas.create_text(416,600,text = " Mission Impossible - Fallout",font = ("Arial Bold",16),fill="#D2691E")
                        canvas.create_text(406,650,text = "Rating - 7.7 ",font = ("Arial Bold",16),fill="#FF8C00")
                        canvas.create_text(980,600,text = '''Ethan Hunt and his IMF team, along with some familiar''',font = ("Arial Bold",12),fill="black")
                        canvas.create_text(980,625,text = '''allies, race against time after a mission gone wrong. ''',font = ("Arial Bold",12),fill="black")
                       
                        
                       
                    
                    global bg3
                    win10 = Toplevel(win1)
                    win10.title("Top 5 Recommendations")
                    win10.geometry("1000x1000")
                    
                    bg3 = ImageTk.PhotoImage(Image.open("2018.jpg"))

                    canvas = Canvas(win10,width = 1000, height = 1000)
                    canvas.pack(fill = "both", expand = True)
                    canvas.create_image(0,0, image=bg3, anchor="nw")

                    

                    canvas.create_text(693,360,text = "Avengers Infinity War ",font = ("Arial Bold",18),fill="white")
                    canvas.create_text(693,460,text = "Black Panther",font = ("Arial Bold",18),fill="white")
                    canvas.create_text(693,660,text = " Mission Impossible - Fallout",font = ("Arial Bold",18),fill="white")
                    
                    
                    win10.bind('<Configure>',resizer)
                    
                    
                    
                    
                    
                elif(year=='2019'):
                    
                    def resizer3(c):
                        global bg23,resized_bg3,new_bg3
                        bg23 = Image.open("2019.png")
                        resized_bg3 = bg23.resize((c.width,c.height), Image.ANTIALIAS)
                        new_bg3 = ImageTk.PhotoImage(resized_bg3)
                        canvas.create_image(0,0, image=new_bg3, anchor="nw")
                        
                        canvas.create_text(800,100,text = "Top Movies of 2019 ",font = ("Arial Bold",20),fill="black")
                        
                        canvas.create_text(400,200,text = "Joker ",font = ("Arial Bold",16),fill="#8A2BE2")
                        canvas.create_text(390,250,text = "Rating - 8.4 ",font = ("Arial Bold",16),fill="#20B2AA")
                        canvas.create_text(990,200,text = '''In Gotham City, mentally troubled comedian Arthur Fleck is disregarded and''',font = ("Arial Bold",12),fill="black")
                        canvas.create_text(990,225,text = '''mistreated by society. He then embarks on a downward spiral of revolution and''',font = ("Arial Bold",12),fill="black")
                        canvas.create_text(990,250,text = '''bloody crime. This path brings him face-to-face with his alter-ego: the Joker.''',font = ("Arial Bold",12),fill="black")
                        
                        
                        canvas.create_text(400,400,text = "Avengers Endgame ",font = ("Arial Bold",16),fill="#8A2BE2")
                        canvas.create_text(390,450,text = "Rating - 8.4 ",font = ("Arial Bold",16),fill="#20B2AA")
                        canvas.create_text(990,400,text = '''After the devastating events of Avengers: Infinity War (2018), the universe is in''',font = ("Arial Bold",12),fill="black")
                        canvas.create_text(990,425,text = '''ruins. With the help of remaining allies, the Avengers assemble once more in order''',font = ("Arial Bold",12),fill="black")
                        canvas.create_text(990,450,text = '''to reverse Thanos' actions and restore balance to the universe.''',font = ("Arial Bold",12),fill="black")
                        
                        
                        
                        canvas.create_text(400,600,text = "The Irishman ",font = ("Arial Bold",16),fill="#8A2BE2")
                        canvas.create_text(390,650,text = "Rating - 7.8 ",font = ("Arial Bold",16),fill="#20B2AA")
                        canvas.create_text(990,600,text = '''An old man recalls his time painting houses for his friend, Jimmy Hoffa,''',font = ("Arial Bold",12),fill="black")
                        canvas.create_text(990,625,text = '''through the 1950-70s. ''',font = ("Arial Bold",12),fill="black")
                        
                        
                        
                        
                        
                    
                    global bg4
                    win11 = Toplevel(win1)
                    win11.title("Top 5 Recommendations")
                    win11.geometry("1000x1000")
                    
                    bg4 = ImageTk.PhotoImage(Image.open("2019.png"))

                    canvas = Canvas(win11,width = 1000, height = 1000)
                    canvas.pack(fill = "both", expand = True)
                    canvas.create_image(0,0, image=bg4, anchor="nw")

                    
                    canvas.create_text(693,560,text = "Joker ",font = ("Arial Bold",18),fill="white")
                    canvas.create_text(693,660,text = "Avengers Endgame ",font = ("Arial Bold",18),fill="white")
                    canvas.create_text(693,760,text = "The Irishman ",font = ("Arial Bold",18),fill="white")
                    
                    win11.bind('<Configure>',resizer3)
                          
                elif(year=='2020'):
                    
                    def resizer4(d):
                        
                        global bg24,resized_bg4,new_bg4
                        bg24 = Image.open("2020.jpg")
                        resized_bg4 = bg24.resize((d.width,d.height), Image.ANTIALIAS)
                        new_bg4 = ImageTk.PhotoImage(resized_bg4)
                        canvas.create_image(0,0, image=new_bg4, anchor="nw")
                        
                        canvas.create_text(800,100,text = "Top Movies of 2020 ",font = ("Arial Bold",20),fill="#556B2F")
                        
                        canvas.create_text(440,200,text = "Soul ",font = ("Arial Bold",16),fill="#6495ED")
                        canvas.create_text(430,250,text = "Rating - 8.1 ",font = ("Arial Bold",16),fill="#2E8B57")
                        canvas.create_text(930,200,text ='''After landing the gig of a lifetime, a New York jazz pianist suddenly''',font = ("Arial Bold",12),fill="black")
                        canvas.create_text(930,225,text ='''finds himself trapped in a strange land between Earth and the afterlife. ''' ,font = ("Arial Bold",12),fill="black")
                        
                        
                        
                        canvas.create_text(440,400,text = "Mank",font = ("Arial Bold",16),fill="#6495ED")
                        canvas.create_text(430,450,text = "Rating - 6.9",font = ("Arial Bold",16),fill="#2E8B57")
                        canvas.create_text(930,400,text ='''1930's Hollywood is reevaluated through the eyes of scathing''',font = ("Arial Bold",12),fill="black")
                        canvas.create_text(930,425,text ='''social critic and alcoholic screenwriter Herman J. Mankiewicz''' ,font = ("Arial Bold",12),fill="black")
                        canvas.create_text(930,450,text ='''as he races to finish the screenplay of Citizen Kane (1941).''' ,font = ("Arial Bold",12),fill="black")
                        
                        
                       
                        
                        canvas.create_text(440,600,text = "Crip Camp ",font = ("Arial Bold",16),fill="#6495ED")      
                        canvas.create_text(430,650,text = "Rating - 7.7 ",font = ("Arial Bold",16),fill="#2E8B57")   
                        canvas.create_text(930,600,text ='''Down the road from Woodstock, a revolution blossomed at a''',font = ("Arial Bold",12),fill="black")
                        canvas.create_text(930,625,text ='''ramshackle summer camp for teenagers with disabilities,''' ,font = ("Arial Bold",12),fill="black")
                        canvas.create_text(930,650,text ='''transforming their lives and igniting a landmark movement.''' ,font = ("Arial Bold",12),fill="black")
                        
                        
                        
                    
                    global bg5
                    win12 = Toplevel(win1)
                    win12.title("Top 5 Recommendations")
                    win12.geometry("1000x1000")
                    
                    bg5 = ImageTk.PhotoImage(Image.open("2020.jpg"))

                    canvas = Canvas(win12,width = 1000, height = 1000)
                    canvas.pack(fill = "both", expand = True)
                    canvas.create_image(0,0, image=bg5, anchor="nw")

                    

                    canvas.create_text(693,360,text = "Soul ",font = ("Arial Bold",18),fill="white")
                    canvas.create_text(693,460,text = "Mank",font = ("Arial Bold",18),fill="white")
                    canvas.create_text(693,760,text = "Crip Camp ",font = ("Arial Bold",18),fill="white")
                       
                    win12.bind('<Configure>',resizer4)    
                              
                   
            global background1
            win1 = Toplevel(win)
            win1.title("Top 5 Recommendations")
            win1.geometry("1000x1000")

            background1 = ImageTk.PhotoImage(Image.open("Img10.jpg"))
            
 
            my_canvas1 = Canvas(win1, width = 1000, height = 1000)
            my_canvas1.pack(fill = "both", expand = True)
            my_canvas1.create_image(0,0, image=background1, anchor="nw")
            my_canvas1.create_text(800,350,text="Year:  " ,font = ("Arial Bold",25),fill="#FEDC56")


            
            clicked = StringVar()
            genre = ttk.Combobox(win1,textvariable = clicked, values = ["2016","2017","2018","2019","2020"],font = ("Arial",14))
            genre_window = my_canvas1.create_window(660,400,anchor="nw",window=genre)

            login_btn = Button(win1,text = " Submit ", font = ("Arial Bold",14),width = 15,bg="blue",fg = "white",command=datatop)
            login_window = my_canvas1.create_window(680,550,anchor = "nw",window=login_btn) 
            
            

            


        def contfunc():

            def contfuncs():
                
                
                                 
                                                          
                def m_rating():
                    
                    list3 = []
                    genres1 = []
                    ratings = []
                    res = {}
                    rating_list = []
                   
                   
                    def data():
                        
                        for rating in ratings:
                            rating_list.append(eval(rating.get()))
                            
                        for key in list3:
                            for value in rating_list:
                                res[key] = value
                                rating_list.remove(value)
                                break           
                                
                        
                        data=pd.DataFrame(res.items(),columns = ['Title','Ratings'])
                        print(data)
                        
                        data.to_excel("C:/Users/swapn/OneDrive/Desktop/Content.xlsx")
                              
                           
                                
                    
                           
                    
                    
                    for i in genre1.curselection():
                                                                                
                        genres1=genre1.get(i)
                        list3.append(genres1)
                    
                                        
                    length = len(list3)
                    
                    win5 = Toplevel(win4)
                    win5.title("Ratings")
                    win5.geometry("1000x1000")
                    
                    label = Label(win5,text = "Ratings for the Movies - Out of 5 ").grid(row=0, column=1)
                    
                    for i in range(length):
                        
                                               
                        my_entry = Entry(win5)
                        label1 = Label(win5, text = str(list3[i])).grid(row=1, column=i) 
                        my_entry.grid(row=2, column=i, pady=5, padx=5)
                        ratings.append(my_entry)
                        
                    btn = Button(win5, text = "Submit",bd = 5,command = data)   
                    btn.grid(row=3, column=2)
  
                    
    
                    
  
                    
        
                    
                                   
                global background4
                
                list1 = []
                
                
                for i in genre.curselection():
                    
                    genres=genre.get(i)
                    list1.append(genres)

               
                
                df = pd.read_excel("E:/Projects/Major Project/movie_data.xlsx")
                
                

                list2 = []
                unique_list = []
                for index, row in df.iterrows():
                    for i in list1:
                        if(i in row['genres']):
                            list2.append(row['title'])
                
                for x in list2:
                    if x not in unique_list:
                         unique_list.append(x)
                        
                    
                         
                    
                    
           
                win4 = Toplevel(win2)
                win4.title("Content Based Filtering")
                win4.geometry("1000x1000")
                
                background4 = ImageTk.PhotoImage(Image.open("img100.jpg"))
            
                my_canvas4 = Canvas(win4, width = 1000, height = 1000)
                my_canvas4.pack(fill = "both", expand = True)
                my_canvas4.create_image(0,0, image=background4, anchor="nw")
                my_canvas4.create_text(810,200,text="Select your favourite Movies:   " ,font = ("Arial Bold",20),fill="#FFFF00")
                
                my_canvas4.create_text(550,300,text="Movie List: " ,font = ("Arial Bold",15),fill="#FFFF00")
                
               
                
                genre1 = Listbox(win4, selectmode = "multiple",width = 40,height = 16)
                
                for each_item in range(len(unique_list)):
                    genre1.insert(END, unique_list[each_item])
                    genre1.itemconfig(each_item,bg = "white" if each_item % 2 == 0 else "#6495ED")

                genre_window1 = my_canvas4.create_window(550,450,window=genre1)
                                                                           
                
                login_btn1 = Button(win4,text = " Submit ", font = ("Arial Bold",14),width = 15,bg="black",fg = "white",command = m_rating)
                login_window1 = my_canvas4.create_window(885,450,anchor = "nw",window=login_btn1) 
                
                
    
                    
            
            global background2
                                 
            genres = []
            win2 = Toplevel(win)
            win2.title("Based On Your Choices")
            win2.geometry("1000x1000")

            background2 = ImageTk.PhotoImage(Image.open("content.jpg"))
            
 

            my_canvas2 = Canvas(win2, width = 1000, height = 1000)
            my_canvas2.pack(fill = "both", expand = True)
            my_canvas2.create_image(0,0, image=background2, anchor="nw")
            my_canvas2.create_text(800,200,text="Select your favourite Genres:  " ,font = ("Arial Bold",20),fill="#FF0000")

            genre = Listbox(win2, selectmode = "multiple",width = 40,height = 16)
            x = ["Adventure","Animation","Action","Children","Crime","Comedy","Drama","Documentary","Fantasy","Film-Noir","Horror","IMAX","Musical","Sci-Fi","Mystery","Romance","Thriller","War","Western"]
  
            for each_item in range(len(x)):
                genre.insert(END, x[each_item])
                genre.itemconfig(each_item,bg = "white" if each_item % 2 == 0 else "#6495ED")

            genre_window = my_canvas2.create_window(550,450,window=genre)

            login_btn = Button(win2,text = " Submit ", font = ("Arial Bold",14),width = 15,bg="black",fg = "white",command = contfuncs)
            login_window = my_canvas2.create_window(850,450,anchor = "nw",window=login_btn) 



        def collfunc():
            
            def collfuncs():
                
                def m_rating():
                    
                    list3 = []
                    genres1 = []
                    ratings = []
                    res = {}
                    rating_list = []
                   
                   
                    def data():
                        
                        
                        for rating in ratings:
                            
                              rating_list.append(eval(rating.get()))
                              
                        for key in list3:
                            for value in rating_list:
                                res[key] = value
                                rating_list.remove(value)
                                break           
                                
                                               
                        data=pd.DataFrame(res.items(),columns = ['Title','Ratings'])
                        print(data)
                                                 
                        data.to_excel("C:/Users/swapn/OneDrive/Desktop/Collaborative.xlsx")   
                                
                                
                    
                            
    
                                
                       
                       
                    
                    for i in genre1.curselection():
                                                                                
                        genres1=genre1.get(i)
                        list3.append(genres1)
                    
                                        
                    length = len(list3)
                    
                    win7 = Toplevel(win6)
                    win7.title("Ratings")
                    win7.geometry("300x300")
                    label = Label(win7,text = "Ratings for the Movies - Out of 5 ").grid(row=0,column=1)
                    
                    for i in range(length):
                        
                        my_entry = Entry(win7)
                        label1 = Label(win7, text = str(list3[i])).grid(row=1,column=i)
                        my_entry.grid(row=2, column=i, pady=5, padx=5)
                        ratings.append(my_entry)
                        
                    btn = Button(win7, text = "Submit",bd = 5,command = data)   
                    btn.grid(row=3,column = 2)
                    
                   
                                                      
                    
                                   
                global background4
                
                list1 = []
                
                
                for i in genre.curselection():
                    
                    genres=genre.get(i)
                    list1.append(genres)

               
                
                df = pd.read_excel("E:/Projects/Major Project/movie_data.xlsx")
                
                

                list2 = []
                unique_list = [] 
                for index, row in df.iterrows():
                    for i in list1:
                        if(i in row['genres']):
                            list2.append(row['title'])
                
                for x in list2:
                    if x not in unique_list:
                        unique_list.append(x)
                        
                
                               
                    
                
                
                win6 = Toplevel(win3)
                win6.title("Collaborative Based Filtering")
                win6.geometry("1000x1000")
                
                background4 = ImageTk.PhotoImage(Image.open("img200.jpg"))
            
                my_canvas4 = Canvas(win6, width = 1000, height = 1000)
                my_canvas4.pack(fill = "both", expand = True)
                my_canvas4.create_image(0,0, image=background4, anchor="nw")
                my_canvas4.create_text(810,200,text="Select your favourite Movies:   " ,font = ("Arial Bold",20),fill="#FFFF00")
                
                my_canvas4.create_text(550,300,text="Movie List: " ,font = ("Arial Bold",15),fill="#FFFF00")
                
               
                
                genre1 = Listbox(win6, selectmode = "multiple",width = 40,height = 16)
                
                for each_item in range(len(unique_list)):
                    genre1.insert(END, unique_list[each_item])
                    genre1.itemconfig(each_item,bg = "white" if each_item % 2 == 0 else "#ADFF2F")

                genre_window1 = my_canvas4.create_window(550,450,window=genre1)
                                                                           
                
                login_btn1 = Button(win6,text = " Submit ", font = ("Arial Bold",14),width = 15,bg="black",fg = "white",command = m_rating)
                login_window1 = my_canvas4.create_window(885,450,anchor = "nw",window=login_btn1) 
                
                
                                    
            
            
            
            
            
            
            global background3
            genres = []
            win3 = Toplevel(win)
            win3.title("Based on Choices of Similar Users")
            win3.geometry("1000x1000")

            background3 = ImageTk.PhotoImage(Image.open("coll.jpg"))
            
 

            my_canvas3 = Canvas(win3, width = 1000, height = 1000)
            my_canvas3.pack(fill = "both", expand = True)
            my_canvas3.create_image(0,0, image=background3, anchor="nw")
            my_canvas3.create_text(800,180,text="Select your favourite Genre:  " ,font = ("Arial Bold",20),fill="#2F4F4F")
            

            genre = Listbox(win3, selectmode = "multiple",width = 40,height = 16)
            x = ["Adventure","Animation","Action","Children","Crime","Comedy","Drama","Documentary","Fantasy","Film-Noir","Horror","IMAX","Musical","Sci-Fi","Mystery","Romance","Thriller","War","Western"]
  
            for each_item in range(len(x)):
        
                genre.insert(END, x[each_item])
                genre.itemconfig(each_item,bg = "white" if each_item % 2 == 0 else "#ADFF2F")

            genre_window = my_canvas3.create_window(540,450,window=genre)

            login_btn = Button(win3,text = " Submit ", font = ("Arial Bold",14),width = 15,bg="green",fg = "white",command = collfuncs)
            login_window = my_canvas3.create_window(810,450,anchor = "nw",window=login_btn) 

       
             

                                
        top10 = Button(win,text = "Top 3 movies ", font = ("Arial Bold",14),width = 25,bg="white",fg="#FF4500",command = top10func)
        top10_window = my_canvas.create_window(200,550,anchor = "nw",window=top10)
        
        cont = Button(win,text = "Content Based Algorithm", font = ("Arial Bold",14),width = 25,bg="white",fg="#3CB371",command = contfunc)
        cont_window = my_canvas.create_window(600,550,anchor = "nw",window=cont)

        coll = Button(win,text = "Collaborative Filtering Algorithm", font = ("Arial Bold",14),width = 25,bg="white",fg="#6495ED",command = collfunc)
        coll_window = my_canvas.create_window(1000,550,anchor = "nw",window=coll)

        

window = tk.Tk()
window.title("Welcome to Movie Recommender System ")
window.geometry("1000x1000")


bg = ImageTk.PhotoImage(Image.open("Img.jpg"))

canvas = Canvas(window, width = 1000, height = 1000)
canvas.pack(fill = "both", expand = True)
canvas.create_image(0,0, image=bg, anchor="nw")

canvas.create_text(750,250,text="So, Let's get started with your movie preferences !",font = ("Arial Bold",30),fill="white")

canvas.create_text(693,490,text = "Name ",font = ("Arial Bold",18),fill="white")

name_entry = Entry(window,font = ("Arial Bold",14),width = 24,bd=0)
name_window = canvas.create_window(660,530,anchor = "nw",window=name_entry)

login_btn = Button(window,text = " Submit ", font = ("Arial Bold",14),width = 15,bg="white",fg = "black",command = submit)
login_window = canvas.create_window(700,650,anchor = "nw",window=login_btn)


window.mainloop()
